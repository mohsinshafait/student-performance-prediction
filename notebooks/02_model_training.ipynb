# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"C:\Users\mohsi\Python\Projects\student_performance_prediction\data\raw_data\student-mat.csv", sep=";")
